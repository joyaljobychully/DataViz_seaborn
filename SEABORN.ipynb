# %% [markdown]
# ?1) Load the inbuilt dataset 'tips'
#
#
#     1. Find the correlation between the attributes.
#     2. Display the heatmap of tips dataset.
#     3. Create a green joint plot with hexagonal points between total bill and tips with tips on x axis.
#     4. Create a green regression plot with hexagonal points between total bill and tip with tip on x axis.
#     5. Create a green kde plot with hexagonal points between total bill and tip with tip on x axis.
#     6. Create a kde plot for total bill
#     7. Check for relation with all attributes diagramatically.
#     8. Check for relation with all attributes diagramatically for male and female separately in coolwarm palette
#     9. Make a histogram of total bill
#     10. Make a histogram of total bill without kde having 30 bins
#     11. Make a rug plot of total_bill
#     10. Plot a bar chart of male and female with ticks, whitegrid and darkgrid background.
#     11. Plot a bar chart of smoker and non-smoker. Figure size should be (12,3)
#     12. Plot a bar chart of day of the week. Remove the spines from the plot.
#     13. Plot a horizontal bar chart of male and female for a poster and notebook. Make the font scale 3
#     14. Plot a bar chart of male and female with mean of total_bill on x axis
#     15. Plot a bar chart of male and female with standard deviation of total_bill on x axis
#     16. Plot a bar chart of smoker and non-smoker with sum of total_bill on x axis
#     17. Plot a bar chart of day of the week with varience total_bill on x axis
#     18. Plot a bar chart of male and female with mean of total_bill on y axis
#     19. Create a boxplot between smoker and total_bill
#     20. Create a rainbow colored boxplot between day and total_bill.
#     21. Create a horizontal boxplot of the whole tips dataframe.
#     22. Create a boxplot for total_bill per day for smokers and non-smokers.
#     23. Include a distribution density with the total_bill per day for smokers and non-smokers in boxplot.
#     24. Include a distribution density with the total_bill per day for smokers and non-smokers on the same box in the boxplot.
#     25. Create a scatter plot of total_bill per day
#     26. Create a scatter plot of total_bill per day with non-collinear dots for male and female
#     27. Create a scatter plot of total_bill per day with distinguishable distribution for male and female
#     28. Create a plot which is a mix of violin plot and scatter plot of total_bill per day
#     29. Create a plot which is a mix of violin plot and scatter plot of total_bill per day inside a violin plot
#     30. Create a bar plot of total_bill per day from general method.
#     31. Display the heatmap of tips dataset in coolwarm color scheme with coefficients of correlation values
#     32. Open flights dataset and make a heatmap of pivot table of flights dataset(passengers value of index months and year columns). Heatmap should be with white lines of width 1 and color scheme magma
#     33. Create a coolwarm clustermap with a normalized scale of pivot table of flights dataset(passengers value of index months and year columns)
#     34. Open the iris data set. Make a plot like pair plot but all the plots should be scatter plots
#     35. Using the iris data set, make a plot like pair plot but histogram along the diagonal, kde plot in the upper triangle and scatter plot in the lower triangle
#     36. Make a histogram pairplot with tips dataset for total_bill. Make the plots vary with time and smoker
#     37. Make a pairplot containing scatter plots with tips dataset for total_bill vs tip. Make the plots vary with time and smoker
#     38. Make a linear fit plot between total_bill and tip for tips dataframe with sex hue. The points should be characterized by distinct markers for male and females of size 100. Make the color scheme to be a creative one from the colormap documentation page.
#     39. Make a linear fit plot between total_bill and tip of tips dataframe with separate diagrams for male smoker,male non-smoker, female smoker, female non-smoker. Aspect ratio should be 0.6 and size should be 8
#     40. Make an area plot with the numerical data from tips dataframe with 0.4 transparency
#     41. Make a stacked bar plot with the numerical data from tips dataframe
#     42. Make a line plot with tip vs total_bil and index vs total_bill for numerical data of tips dataframe with figure size (12,3) and line width 1
#     43. Make a scatter plot with tip vs total_bil for numerical data of tips dataframe. Separate the points for male and female

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# 1. Find the correlation between the attributes.

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# 3. Create a green joint plot with hexagonal points between total bill and tips with tips on x axis.

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex',color='g')

# %% [markdown]
# 4. Create a green regression plot between total bill and tip with tip on x axis.

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg',color='g')

# %% [markdown]
# 5. Create a green kde plot between total bill and tip with tip on x axis.

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde',color='g')

# %% [markdown]
# 6. Create a kde plot for total bill

# %%
sns.kdeplot(x='total_bill',data=df)

# %% [markdown]
# 7. Check for relation with all attributes diagramatically.

# %%
sns.pairplot(df)

# %% [markdown]
# 8. Check for relation with all attributes diagramatically for male and female separately.

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# 9. Check for relation with all attributes diagramatically for smokers and non-smokers separately.

# %%
sns.pairplot(df,hue='smoker')

# %% [markdown]
# 10. Create a histogram of tip column

# %%
sns.distplot(df.tip)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 11. Create a histogram of tip column without kde and 10 bins.

# %%
sns.distplot(df.tip,kde=False,bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 12. Plot a bar chart of male and female with ticks, whitegrid and darkgrid background.

# %%
sns.countplot(df.sex)
sns.set_style('ticks')
sns.countplot(df.sex)
sns.set_style('whitegrid')
sns.countplot(df.sex)
sns.set_style('darkgrid')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
#  13. Plot a bar chart of smoker and non-smoker. Figure size should be (12,3)

# %%
plt.figure(figsize=(12,3))
sns.countplot(df.smoker)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 14. Plot a bar chart of day of the week in white background. Remove the spines from the plot.

# %%
sns.countplot(df.day)
sns.despine(left=True,bottom=True)
sns.set_style('white')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 15. Plot a horizontal bar chart of male and female for a poster and notebook. Make the font scale 3

# %%
sns.countplot(y='sex',data=df)
sns.set_context('poster',font_scale=3)

# %% [markdown]
# 16. Plot a bar chart of male and female with mean of total_bill on x axis

# %%
sns.barplot(x='total_bill',y='sex',data=df)

# %% [markdown]
# 17. Plot a bar chart of male and female with standard deviation of total_bill on x axis

# %%
sns.barplot(x='total_bill',y='sex',data=df,estimator=np.std)

# %% [markdown]
# 18. Plot a bar chart of smoker and non-smoker with sum of total_bill on x axis

# %%
sns.barplot(x='total_bill',y='smoker',data=df,estimator=sum)

# %% [markdown]
# 19. Plot a bar chart of day of the week with varience total_bill on x axis

# %%
sns.barplot(x='total_bill',y='day',data=df,estimator=np.var)

# %% [markdown]
# 20. Plot a bar chart of male and female with mean of total_bill on y axis

# %%
sns.barplot(x='sex',y='total_bill',data=df)

# %% [markdown]
# 21. Create a boxplot between smoker and total_bill

# %%
sns.boxplot(x='smoker',y='total_bill',data=df)

# %% [markdown]
# 22. Create a rainbow colored boxplot between day and total_bill.

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow')

# %% [markdown]
# 23. Create a horizontal boxplot of the whole tips dataframe.

# %%
sns.boxplot(data=df,orient='h')

# %% [markdown]
# 24. Create a boxplot for total_bill per day for smokers and non-smokers.

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')

# %% [markdown]
# 25. Include a distribution density with the total_bill per day for smokers and non-smokers in boxplot.

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='smoker')

# %% [markdown]
# 26. Include a distribution density with the total_bill per day for smokers and non-smokers on the same box in the boxplot.

# %%
sns.violinplot(x='total_bill',y='day',data=df,hue='smoker',split=True)

# %% [markdown]
# 28. Create a strip plot of total_bill per day with non-collinear dots for male and female

# %%
sns.stripplot(x='day',y='total_bill',data=df,jitter=True)

# %% [markdown]
# 29. Create a strip plot of total_bill per day with distinguishable distribution for male and female

# %%
sns.stripplot(x='day',y='total_bill',data=df,jitter=True,hue='sex')

# %% [markdown]
# 30. Create a plot which is a mix of violin plot and strip plot of total_bill per day

# %%
sns.swarmplot(x='day',y='total_bill',data=df)

# %% [markdown]
#   31. Create a plot which is a mix of violin plot and strip plot of total_bill per day inside a violin plot

# %%
sns.violinplot(x='day',y='total_bill',data=df,color='white')
sns.swarmplot(x='day',y='total_bill',data=df,color='black')

# %% [markdown]
# 32. Create a bar plot of total_bill per day from general method.

# %%
sns.factorplot(x='day',y='total_bill',data=df,kind='bar',estimator=np.std)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=df,kind='violin')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=df,kind='box')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=df,kind='strip')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=df,kind='swarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# 33. Display the heatmap of tips dataset in coolwarm color scheme with coefficients of correlation values

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')

# %% [markdown]
#  34. Open flights dataset and make a heatmap of pivot table of flights dataset(passengers value of index months and year columns). Heatmap should be with white lines of width 1 and color scheme magma

# %%
df1 = sns.load_dataset('flights')

# %%
df1.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fp = df1.pivot_table(values='passengers',index='month',columns='year')

# %%
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp,cmap='magma',linewidth=1,linecolor='white')

# %% [markdown]
#  35. Create a coolwarm clustermap with a normalized scale of pivot table of flights dataset(passengers value of index months and year columns)

# %%
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
#  36. Open the iris data set. Make a plot like pair plot but all the plots should be scatter plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ir = sns.load_dataset('iris')

# %%
ir.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(ir)
g.map(plt.scatter)

# %% [markdown]
# 37. Using the iris data set, make a plot like pair plot but histogram along the diagonal, kde plot in the upper triangle and scatter plot in the lower triangle

# %%
h = sns.PairGrid(ir)
h.map_diag(sns.distplot)
h.map_upper(sns.kdeplot)
h.map_lower(plt.scatter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# 38. Make a histogram pairplot with tips dataset for total_bill. Make the plots vary with time and smoker

# %%
p = sns.FacetGrid(data=df,row='smoker',col='time')
p.map(sns.distplot,'total_bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# 39. Make a pairplot containing scatter plots with tips dataset for total_bill vs tip. Make the plots vary with time and smoker

# %%
q = sns.FacetGrid(data=df,row='smoker',col='time')
q.map(plt.scatter,'tip','total_bill')

# %% [markdown]
# 40. Make a linear fit plot between total_bill and tip for tips dataframe with sex hue. The points should be characterized by distinct markers for male and females of size 100

# %%
sns.lmplot(x='total_bill',y='tip',data=df,hue='sex',markers=['s','*'],scatter_kws={'s':100})

# %% [markdown]
# 41. Make a linear fit plot between total_bill and tip of tips dataframe with separate diagrams for male smoker,male non-smoker, female smoker, female non-smoker. Aspect ratio should be 0.6 and size should be 8

# %%
sns.lmplot(x='total_bill',y='tip',data=df,col='sex',row='smoker',aspect=0.6,size=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df_ = df.loc[:,['total_bill','tip','size']]

# %%
df_.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# 42. Make an area plot with the numerical data from tips dataframe with 0.4 transparency

# %%
df_.plot(kind='area',alpha=0.4)

# %% [markdown]
# 43. Make a stacked bar plot with the numerical data from tips dataframe

# %%
df_.plot(kind='bar',stacked=True)

# %%
df_.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
#  44. Make a line plot with tip vs total_bill of tips dataframe with figure size (12,3) and line width 1

# %%
df_.plot(kind='line',x='tip',y='total_bill',figsize=(12,3),lw=1)

# %% [markdown]
# 45. Make a scatter plot with tip vs total_bil vs size in coolwarm for numerical data of tips dataframe

# %%
df_.plot(kind='scatter',x='total_bill',y='tip',c='size',cmap='coolwarm')

# %% [markdown]
# 46. Make a scatter plot with tip vs total_bil vs 0.1 times the size for numerical data of tips dataframe

# %%
df_.plot(kind='scatter',x='total_bill',y='tip',s=df_.size*0.1)

# %% [markdown]
# 47. Make a random 1000X2 column dataframe with column names a,b and plot a hexagonal bin plot in coolwarm with grid size 25

# %%
df47 = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df47.head()
# Out:
#           a         b
# 0 -1.057237  0.995420
# 1  1.023175 -1.778530
# 2  0.143896  0.521810
# 3 -0.398582  0.081150
# 4  2.111158 -1.348758

# %%
df47.plot(kind='hexbin',x='a',y='b',gridsize=25,cmap='coolwarm')

# %% [markdown]
# 48. Make a kde plot of total_bil for numerical data of tips dataframe

# %%
df_.total_bill.plot(kind='kde')

# %% [markdown]
# 49. Make a kde plot of numerical data of tips dataframe

# %%
df_.plot(kind='kde')
